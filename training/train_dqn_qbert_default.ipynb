# %% [markdown]
# # DQN: Qbert (Default Hyperparameters)
#
# **Algorithm:** DQN
# **Environment:** Qbert (`QbertNoFrameskip-v4`)

# %%
# Configuration
ALGO            = "dqn"
ENV_KEY         = "qbert"
TOTAL_TIMESTEPS = 1_000_000
CHECKPOINT_FREQ = 100_000
LEARNING_RATE   = None
RUN_NAME        = None

# %%
import os

import ale_py
import gymnasium as gym
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

gym.register_envs(ale_py)

ENV_IDS = {
    "qbert":      "QbertNoFrameskip-v4",
    "donkeykong": "DonkeyKongNoFrameskip-v4",
}

run_id = f"{ALGO}_{ENV_KEY}" + (f"_{RUN_NAME}" if RUN_NAME else "")
checkpoint_dir = os.path.join("checkpoints", run_id)
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs("logs", exist_ok=True)

print(f"Run ID      : {run_id}")
print(f"Checkpoints : {checkpoint_dir}")
# Out:
# Run ID      : dqn_qbert
# Checkpoints : checkpoints/dqn_qbert

# %%
n_envs = 8 if ALGO == "ppo" else 1
vec_env = make_atari_env(ENV_IDS[ENV_KEY], n_envs=n_envs, seed=0)
vec_env = VecFrameStack(vec_env, n_stack=4)
print(f"Environment : {ENV_IDS[ENV_KEY]}  |  n_envs: {n_envs}")
# Out:
# Environment : QbertNoFrameskip-v4  |  n_envs: 1
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# ## Fresh Training
#
# Checkpoints saved automatically to `checkpoints/dqn_qbert/` every 100,000 steps.

# %%
if ALGO == "dqn":
    kwargs = dict(
        verbose=1, device="cpu", tensorboard_log="logs",
        buffer_size=100_000, learning_starts=10_000,
        batch_size=32, train_freq=4, target_update_interval=1_000,
    )
    if LEARNING_RATE is not None:
        kwargs["learning_rate"] = LEARNING_RATE
    model = DQN("CnnPolicy", vec_env, **kwargs)
elif ALGO == "ppo":
    kwargs = dict(
        verbose=1, device="cpu", tensorboard_log="logs",
        n_steps=128, batch_size=256, n_epochs=4, ent_coef=0.01, clip_range=0.1,
    )
    if LEARNING_RATE is not None:
        kwargs["learning_rate"] = LEARNING_RATE
    model = PPO("CnnPolicy", vec_env, **kwargs)

print(f"Algorithm : {ALGO.upper()}")
print(f"Device    : {model.device}")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Algorithm : DQN
# Device    : cpu

# %%
checkpoint_callback = CheckpointCallback(
    save_freq=max(CHECKPOINT_FREQ // n_envs, 1),
    save_path=checkpoint_dir,
    name_prefix="checkpoint",
    save_replay_buffer=False,
    save_vecnormalize=True,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=checkpoint_callback,
    tb_log_name=run_id,
    progress_bar=True,
    reset_num_timesteps=True,
)

final_path = os.path.join(checkpoint_dir, "final_model")
model.save(final_path)
print(f"\nTraining complete. Final model saved to: {final_path}.zip")
# Out:
# Logging to logs/dqn_qbert_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.32e+03 |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1149     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 315      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.24e+03 |
# |    ep_rew_mean      | 87.5     |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1337     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 594      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.33e+03 |
# ...

# %% [markdown]
# ---
#
# ## Resume Training
#
# Demonstrates loading a saved checkpoint and continuing training.
# The step counter continues from where it left off (`reset_num_timesteps=False`).

# %%
# Resume Configuration
RESUME_PATH      = "checkpoints/dqn_qbert/checkpoint_500000_steps.zip"
RESUME_TIMESTEPS = 200_000

# %%
cls = DQN if ALGO == "dqn" else PPO
model = cls.load(RESUME_PATH, env=vec_env, tensorboard_log="logs", device="cpu")
print(f"Loaded checkpoint: {RESUME_PATH}")
# Out:
# Wrapping the env in a VecTransposeImage.
# Loaded checkpoint: checkpoints/dqn_qbert/checkpoint_500000_steps.zip

# %%
checkpoint_callback = CheckpointCallback(
    save_freq=max(CHECKPOINT_FREQ // n_envs, 1),
    save_path=checkpoint_dir,
    name_prefix="checkpoint",
    save_replay_buffer=False,
    save_vecnormalize=True,
)

model.learn(
    total_timesteps=RESUME_TIMESTEPS,
    callback=checkpoint_callback,
    tb_log_name=run_id,
    progress_bar=True,
    reset_num_timesteps=False,
)

final_path = os.path.join(checkpoint_dir, "final_model")
model.save(final_path)
print(f"\nResumed training complete. Final model saved to: {final_path}.zip")
# Out:
# Logging to logs/dqn_qbert_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 812      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 60       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 500785   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00772  |
# |    n_updates        | 122695   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.49e+03 |
# |    ep_rew_mean      | 803      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 61       |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 501414   |
# ...
