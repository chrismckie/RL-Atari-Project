# %% [markdown]
# # DQN: Qbert (Hyperparameter Variation: lr=5e-5)
#
# **Algorithm:** DQN
# **Environment:** Qbert (`QbertNoFrameskip-v4`)
# **Learning rate:** 5e-5 (lower than default 1e-4)

# %%
# Configuration
ALGO            = "dqn"
ENV_KEY         = "qbert"
TOTAL_TIMESTEPS = 1_000_000
CHECKPOINT_FREQ = 100_000
LEARNING_RATE   = 5e-5
RUN_NAME        = "lr5e-5"

# %%
import os

import ale_py
import gymnasium as gym
from stable_baselines3 import DQN, PPO
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack

gym.register_envs(ale_py)

ENV_IDS = {
    "qbert":      "QbertNoFrameskip-v4",
    "donkeykong": "DonkeyKongNoFrameskip-v4",
}

run_id = f"{ALGO}_{ENV_KEY}" + (f"_{RUN_NAME}" if RUN_NAME else "")
checkpoint_dir = os.path.join("checkpoints", run_id)
os.makedirs(checkpoint_dir, exist_ok=True)
os.makedirs("logs", exist_ok=True)

print(f"Run ID      : {run_id}")
print(f"Checkpoints : {checkpoint_dir}")
# Out:
# Run ID      : dqn_qbert_lr5e-5
# Checkpoints : checkpoints/dqn_qbert_lr5e-5

# %%
n_envs = 8 if ALGO == "ppo" else 1
vec_env = make_atari_env(ENV_IDS[ENV_KEY], n_envs=n_envs, seed=0)
vec_env = VecFrameStack(vec_env, n_stack=4)
print(f"Environment : {ENV_IDS[ENV_KEY]}  |  n_envs: {n_envs}")
# Out:
# Environment : QbertNoFrameskip-v4  |  n_envs: 1
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]

# %% [markdown]
# ## Fresh Training
#
# Checkpoints saved automatically to `checkpoints/dqn_qbert_lr5e-5/` every 100,000 steps.

# %%
if ALGO == "dqn":
    kwargs = dict(
        verbose=1, device="cpu", tensorboard_log="logs",
        buffer_size=100_000, learning_starts=10_000,
        batch_size=32, train_freq=4, target_update_interval=1_000,
    )
    if LEARNING_RATE is not None:
        kwargs["learning_rate"] = LEARNING_RATE
    model = DQN("CnnPolicy", vec_env, **kwargs)
elif ALGO == "ppo":
    kwargs = dict(
        verbose=1, device="cpu", tensorboard_log="logs",
        n_steps=128, batch_size=256, n_epochs=4, ent_coef=0.01, clip_range=0.1,
    )
    if LEARNING_RATE is not None:
        kwargs["learning_rate"] = LEARNING_RATE
    model = PPO("CnnPolicy", vec_env, **kwargs)

print(f"Algorithm     : {ALGO.upper()}")
print(f"Learning rate : {LEARNING_RATE}")
print(f"Device        : {model.device}")
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# Algorithm     : DQN
# Learning rate : 5e-05
# Device        : cpu

# %%
checkpoint_callback = CheckpointCallback(
    save_freq=max(CHECKPOINT_FREQ // n_envs, 1),
    save_path=checkpoint_dir,
    name_prefix="checkpoint",
    save_replay_buffer=False,
    save_vecnormalize=True,
)

model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=checkpoint_callback,
    tb_log_name=run_id,
    log_interval=100,
    progress_bar=True,
    reset_num_timesteps=True,
)

final_path = os.path.join(checkpoint_dir, "final_model")
model.save(final_path)
print(f"\nTraining complete. Final model saved to: {final_path}.zip")
# Out:
# Logging to logs/dqn_qbert_lr5e-5_1
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.38e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.921    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1529     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 8270     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.38e+03 |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 144      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 16566    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0162   |
# |    n_updates        | 1641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.37e+03 |
# |    ep_rew_mean      | 197      |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 96       |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 24529    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0164   |
# |    n_updates        | 3632     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.36e+03 |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 82       |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 32442    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.013    |
# |    n_updates        | 5610     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.36e+03 |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.612    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 76       |
# |    time_elapsed     | 535      |
# |    total_timesteps  | 40825    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0202   |
# |    n_updates        | 7706     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.35e+03 |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 73       |
# |    time_elapsed     | 668      |
# |    total_timesteps  | 48862    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00683  |
# |    n_updates        | 9715     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.37e+03 |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 70       |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 57371    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.103    |
# |    n_updates        | 11842    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.38e+03 |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.378    |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 69       |
# |    time_elapsed     | 944      |
# |    total_timesteps  | 65440    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0289   |
# |    n_updates        | 13859    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.4e+03  |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.295    |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 68       |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 74221    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0135   |
# |    n_updates        | 16055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.42e+03 |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 67       |
# |    time_elapsed     | 1229     |
# |    total_timesteps  | 82902    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00782  |
# |    n_updates        | 18225    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.43e+03 |
# |    ep_rew_mean      | 247      |
# |    exploration_rate | 0.129    |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 66       |
# |    time_elapsed     | 1374     |
# |    total_timesteps  | 91710    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0444   |
# |    n_updates        | 20427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.48e+03 |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 65       |
# |    time_elapsed     | 1532     |
# |    total_timesteps  | 101018   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00635  |
# |    n_updates        | 22754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.52e+03 |
# |    ep_rew_mean      | 283      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 65       |
# |    time_elapsed     | 1697     |
# |    total_timesteps  | 110838   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0198   |
# |    n_updates        | 25209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.57e+03 |
# |    ep_rew_mean      | 294      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 64       |
# |    time_elapsed     | 1860     |
# |    total_timesteps  | 120649   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0283   |
# |    n_updates        | 27662    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 308      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 64       |
# |    time_elapsed     | 2032     |
# |    total_timesteps  | 130555   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0254   |
# |    n_updates        | 30138    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | 333      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 63       |
# |    time_elapsed     | 2196     |
# |    total_timesteps  | 140359   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.149    |
# |    n_updates        | 32589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | 408      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 63       |
# |    time_elapsed     | 2385     |
# |    total_timesteps  | 151495   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.023    |
# |    n_updates        | 35373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | 478      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 63       |
# |    time_elapsed     | 2588     |
# |    total_timesteps  | 163495   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0461   |
# |    n_updates        | 38373    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | 504      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 62       |
# |    time_elapsed     | 2772     |
# |    total_timesteps  | 173909   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0139   |
# |    n_updates        | 40977    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 552      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 62       |
# |    time_elapsed     | 2995     |
# |    total_timesteps  | 186577   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00829  |
# |    n_updates        | 44144    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 537      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 62       |
# |    time_elapsed     | 3220     |
# |    total_timesteps  | 199873   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0187   |
# |    n_updates        | 47468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 519      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2200     |
# |    fps              | 62       |
# |    time_elapsed     | 3414     |
# |    total_timesteps  | 211677   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.027    |
# |    n_updates        | 50419    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 509      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 61       |
# |    time_elapsed     | 3599     |
# |    total_timesteps  | 222925   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0105   |
# |    n_updates        | 53231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.95e+03 |
# |    ep_rew_mean      | 474      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2400     |
# |    fps              | 61       |
# |    time_elapsed     | 3775     |
# |    total_timesteps  | 233797   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00426  |
# |    n_updates        | 55949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 440      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2500     |
# |    fps              | 61       |
# |    time_elapsed     | 3958     |
# |    total_timesteps  | 244952   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0142   |
# |    n_updates        | 58737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 418      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2600     |
# |    fps              | 61       |
# |    time_elapsed     | 4154     |
# |    total_timesteps  | 256803   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0176   |
# |    n_updates        | 61700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 430      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2700     |
# |    fps              | 61       |
# |    time_elapsed     | 4351     |
# |    total_timesteps  | 268894   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0358   |
# |    n_updates        | 64723    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 467      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2800     |
# |    fps              | 61       |
# |    time_elapsed     | 4585     |
# |    total_timesteps  | 283388   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0624   |
# |    n_updates        | 68346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 508      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 61       |
# |    time_elapsed     | 4799     |
# |    total_timesteps  | 296659   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0275   |
# |    n_updates        | 71664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 560      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 61       |
# |    time_elapsed     | 5001     |
# |    total_timesteps  | 309154   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0672   |
# |    n_updates        | 74788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.2e+03  |
# |    ep_rew_mean      | 597      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 61       |
# |    time_elapsed     | 5216     |
# |    total_timesteps  | 322463   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0161   |
# |    n_updates        | 78115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3200     |
# |    fps              | 61       |
# |    time_elapsed     | 5427     |
# |    total_timesteps  | 335343   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0181   |
# |    n_updates        | 81335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 622      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3300     |
# |    fps              | 61       |
# |    time_elapsed     | 5659     |
# |    total_timesteps  | 349489   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0102   |
# |    n_updates        | 84872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 614      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3400     |
# |    fps              | 61       |
# |    time_elapsed     | 5860     |
# |    total_timesteps  | 361764   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0117   |
# |    n_updates        | 87940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 610      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3500     |
# |    fps              | 61       |
# |    time_elapsed     | 6112     |
# |    total_timesteps  | 374789   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0142   |
# |    n_updates        | 91197    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 606      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3600     |
# |    fps              | 61       |
# |    time_elapsed     | 6333     |
# |    total_timesteps  | 386859   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0108   |
# |    n_updates        | 94214    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 607      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3700     |
# |    fps              | 60       |
# |    time_elapsed     | 6588     |
# |    total_timesteps  | 400939   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.006    |
# |    n_updates        | 97734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 604      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3800     |
# |    fps              | 60       |
# |    time_elapsed     | 6823     |
# |    total_timesteps  | 414383   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0722   |
# |    n_updates        | 101095   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 594      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 60       |
# |    time_elapsed     | 7057     |
# |    total_timesteps  | 428687   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00527  |
# |    n_updates        | 104671   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 565      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4000     |
# |    fps              | 60       |
# |    time_elapsed     | 7288     |
# |    total_timesteps  | 442492   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.02     |
# |    n_updates        | 108122   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 538      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 60       |
# |    time_elapsed     | 7542     |
# |    total_timesteps  | 457376   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0523   |
# |    n_updates        | 111843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 521      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4200     |
# |    fps              | 60       |
# |    time_elapsed     | 7764     |
# |    total_timesteps  | 470910   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0439   |
# |    n_updates        | 115227   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.3e+03  |
# |    ep_rew_mean      | 538      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4300     |
# |    fps              | 60       |
# |    time_elapsed     | 7993     |
# |    total_timesteps  | 484823   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00955  |
# |    n_updates        | 118705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 600      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4400     |
# |    fps              | 60       |
# |    time_elapsed     | 8256     |
# |    total_timesteps  | 499541   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0241   |
# |    n_updates        | 122385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 676      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4500     |
# |    fps              | 60       |
# |    time_elapsed     | 8505     |
# |    total_timesteps  | 514476   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0103   |
# |    n_updates        | 126118   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 703      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4600     |
# |    fps              | 60       |
# |    time_elapsed     | 8725     |
# |    total_timesteps  | 527866   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0106   |
# |    n_updates        | 129466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 713      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4700     |
# |    fps              | 60       |
# |    time_elapsed     | 8963     |
# |    total_timesteps  | 541875   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0066   |
# |    n_updates        | 132968   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.29e+03 |
# |    ep_rew_mean      | 702      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4800     |
# |    fps              | 60       |
# |    time_elapsed     | 9190     |
# |    total_timesteps  | 555398   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0558   |
# |    n_updates        | 136349   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 640      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4900     |
# |    fps              | 60       |
# |    time_elapsed     | 9422     |
# |    total_timesteps  | 569420   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0188   |
# |    n_updates        | 139854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.27e+03 |
# |    ep_rew_mean      | 662      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5000     |
# |    fps              | 60       |
# |    time_elapsed     | 9644     |
# |    total_timesteps  | 583065   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00304  |
# |    n_updates        | 143266   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.27e+03 |
# |    ep_rew_mean      | 678      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5100     |
# |    fps              | 60       |
# |    time_elapsed     | 9871     |
# |    total_timesteps  | 597078   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00881  |
# |    n_updates        | 146769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 694      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5200     |
# |    fps              | 60       |
# |    time_elapsed     | 10102    |
# |    total_timesteps  | 611612   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00421  |
# |    n_updates        | 150402   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.34e+03 |
# |    ep_rew_mean      | 780      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5300     |
# |    fps              | 60       |
# |    time_elapsed     | 10342    |
# |    total_timesteps  | 626411   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00831  |
# |    n_updates        | 154102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | 776      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5400     |
# |    fps              | 60       |
# |    time_elapsed     | 10569    |
# |    total_timesteps  | 640011   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0114   |
# |    n_updates        | 157502   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.28e+03 |
# |    ep_rew_mean      | 747      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5500     |
# |    fps              | 60       |
# |    time_elapsed     | 10779    |
# |    total_timesteps  | 652772   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0679   |
# |    n_updates        | 160692   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.22e+03 |
# |    ep_rew_mean      | 732      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5600     |
# |    fps              | 60       |
# |    time_elapsed     | 11017    |
# |    total_timesteps  | 665806   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0408   |
# |    n_updates        | 163951   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.19e+03 |
# |    ep_rew_mean      | 652      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5700     |
# |    fps              | 60       |
# |    time_elapsed     | 11262    |
# |    total_timesteps  | 679865   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0555   |
# |    n_updates        | 167466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.21e+03 |
# |    ep_rew_mean      | 647      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5800     |
# |    fps              | 60       |
# |    time_elapsed     | 11503    |
# |    total_timesteps  | 693953   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0109   |
# |    n_updates        | 170988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.31e+03 |
# |    ep_rew_mean      | 700      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 5900     |
# |    fps              | 60       |
# |    time_elapsed     | 11758    |
# |    total_timesteps  | 709043   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00885  |
# |    n_updates        | 174760   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.37e+03 |
# |    ep_rew_mean      | 747      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6000     |
# |    fps              | 60       |
# |    time_elapsed     | 11999    |
# |    total_timesteps  | 723538   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00587  |
# |    n_updates        | 178384   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.4e+03  |
# |    ep_rew_mean      | 787      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6100     |
# |    fps              | 60       |
# |    time_elapsed     | 12246    |
# |    total_timesteps  | 738408   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0109   |
# |    n_updates        | 182101   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 800      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6200     |
# |    fps              | 60       |
# |    time_elapsed     | 12483    |
# |    total_timesteps  | 752966   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00971  |
# |    n_updates        | 185741   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.46e+03 |
# |    ep_rew_mean      | 826      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6300     |
# |    fps              | 60       |
# |    time_elapsed     | 12743    |
# |    total_timesteps  | 769022   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.024    |
# |    n_updates        | 189755   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.44e+03 |
# |    ep_rew_mean      | 825      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6400     |
# |    fps              | 60       |
# |    time_elapsed     | 12989    |
# |    total_timesteps  | 783069   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0207   |
# |    n_updates        | 193267   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.42e+03 |
# |    ep_rew_mean      | 784      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6500     |
# |    fps              | 60       |
# |    time_elapsed     | 13237    |
# |    total_timesteps  | 797318   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00764  |
# |    n_updates        | 196829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.38e+03 |
# |    ep_rew_mean      | 816      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6600     |
# |    fps              | 60       |
# |    time_elapsed     | 13481    |
# |    total_timesteps  | 811083   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0534   |
# |    n_updates        | 200270   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.26e+03 |
# |    ep_rew_mean      | 756      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6700     |
# |    fps              | 60       |
# |    time_elapsed     | 13708    |
# |    total_timesteps  | 823990   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0309   |
# |    n_updates        | 203497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.23e+03 |
# |    ep_rew_mean      | 743      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6800     |
# |    fps              | 60       |
# |    time_elapsed     | 13942    |
# |    total_timesteps  | 837385   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00716  |
# |    n_updates        | 206846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 766      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 6900     |
# |    fps              | 60       |
# |    time_elapsed     | 14166    |
# |    total_timesteps  | 850142   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00426  |
# |    n_updates        | 210035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 740      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7000     |
# |    fps              | 59       |
# |    time_elapsed     | 14403    |
# |    total_timesteps  | 863691   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00171  |
# |    n_updates        | 213422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 746      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7100     |
# |    fps              | 59       |
# |    time_elapsed     | 14624    |
# |    total_timesteps  | 876374   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00604  |
# |    n_updates        | 216593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.16e+03 |
# |    ep_rew_mean      | 796      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7200     |
# |    fps              | 59       |
# |    time_elapsed     | 14863    |
# |    total_timesteps  | 890060   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0402   |
# |    n_updates        | 220014   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 840      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7300     |
# |    fps              | 59       |
# |    time_elapsed     | 15090    |
# |    total_timesteps  | 902952   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0136   |
# |    n_updates        | 223237   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 819      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7400     |
# |    fps              | 59       |
# |    time_elapsed     | 15322    |
# |    total_timesteps  | 915841   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0175   |
# |    n_updates        | 226460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 807      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7500     |
# |    fps              | 59       |
# |    time_elapsed     | 15536    |
# |    total_timesteps  | 928561   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0104   |
# |    n_updates        | 229640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.14e+03 |
# |    ep_rew_mean      | 780      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7600     |
# |    fps              | 59       |
# |    time_elapsed     | 15763    |
# |    total_timesteps  | 942258   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.00712  |
# |    n_updates        | 233064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.24e+03 |
# |    ep_rew_mean      | 915      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7700     |
# |    fps              | 59       |
# |    time_elapsed     | 16014    |
# |    total_timesteps  | 957425   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0137   |
# |    n_updates        | 236856   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.32e+03 |
# |    ep_rew_mean      | 1.03e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7800     |
# |    fps              | 59       |
# |    time_elapsed     | 16259    |
# |    total_timesteps  | 972252   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.16     |
# |    n_updates        | 240562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.33e+03 |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 7900     |
# |    fps              | 59       |
# |    time_elapsed     | 16492    |
# |    total_timesteps  | 985356   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.116    |
# |    n_updates        | 243838   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.35e+03 |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 8000     |
# |    fps              | 59       |
# |    time_elapsed     | 16750    |
# |    total_timesteps  | 999395   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 0.0097   |
# |    n_updates        | 247348   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training complete. Final model saved to: checkpoints/dqn_qbert_lr5e-5/final_model.zip
